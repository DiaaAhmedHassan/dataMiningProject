# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing Data

# %%
original_houses_data = pd.read_csv('./data/Housing.csv')
original_houses_data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7229300521  20141013T000000  231300.0         2       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
original_houses_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580306e+09  5.400886e+05      3.370795      2.114757   2079.899736
# std    2.876570e+09  3.671268e+05      0.930105      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
original_houses_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# *as we see here, there is no null values in the data set*

# %%
to_drop = ['id', 'waterfront', 'zipcode', 'date', 'yr_renovated']
edited_feature_houses = original_houses_data.drop(to_drop, axis=1)
original_houses_data.head(11)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7229300521  20141013T000000   231300.0         2       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0       5650     1.0           0     0  ...      7        1180              0
# 1       7242     2.0           0     0  ...      7        2170            400
# 2      10000     1.0           0     0  ...      6         770              0
# 3       5000     1.0           0     0  ...      7        1050            910
# 4       8080     1.0           0     0  ...      8        1680              0
# 5     101930     1.0           0     0  ...     11        3890           1530
# 6       6819     2.0           0     0  ...      7        1715              0
# 7       9711     1.0           0     0  ...      7        1060              0
# 8       7470     1.0           0     0  ...      7        1050            730
# 9       6560     2.0           0     0  ...      7        1890              0
# 10      9796     1.0           0     0  ...      8        1860           1700
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0       1955             0    98178  47.5112 -122.257           1340
# 1       1951          1991    98125  47.7210 -122.319           1690
# 2       1933             0    98028  47.7379 -122.233           2720
# 3       1965             0    98136  47.5208 -122.393           1360
# 4       1987             0    98074  47.6168 -122.045           1800
# 5       2001             0    98053  47.6561 -122.005           4760
# 6       1995             0    98003  47.3097 -122.327           2238
# 7       1963             0    98198  47.4095 -122.315           1650
# 8       1960             0    98146  47.5123 -122.337           1780
# 9       2003             0    98038  47.3684 -122.031           2390
# 10      1965             0    98007  47.6007 -122.145           2210
#
#     sqft_lot15
# 0         5650
# 1         7639
# 2         8062
# 3         5000
# 4         7503
# 5       101930
# 6         6819
# 7         9711
# 8         8113
# 9         7570
# 10        8925
#
# [11 rows x 21 columns]

# %%
# remove duplicates
houses_no_duplicates = edited_feature_houses.drop_duplicates()
houses_no_duplicates.shape
# Out:
# (21608, 16)

# %%
# fix some columns
columns_list = ['bedrooms', 'bathrooms', 'floors']
unique_values = houses_no_duplicates[columns_list].apply(pd.Series.unique)
unique_values
# Out:
# bedrooms            [2, 3, 4, 5, 1, 6, 7, 0, 8, 9, 11, 10, 33]
# bathrooms    [1.0, 2.25, 3.0, 2.0, 4.5, 1.5, 2.5, 1.75, 2.7...
# floors                          [1.0, 2.0, 1.5, 3.0, 2.5, 3.5]
# dtype: object

# %% [markdown]
# *As we see here, there are some logical mistakes regarding <br>
# the number of floors and bathrooms, we need to fix that*

# %%
columns_list = ['bathrooms', 'floors']
houses = houses_no_duplicates.copy()
houses[columns_list] = houses_no_duplicates[columns_list].astype(int)
houses.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  231300.0         2          1         1180      5650       1     0
# 1  538000.0         3          2         2570      7242       2     0
# 2  180000.0         2          1          770     10000       1     0
# 3  604000.0         4          3         1960      5000       1     0
# 4  510000.0         3          2         1680      8080       1     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built      lat     long  \
# 0          3      7        1180              0      1955  47.5112 -122.257
# 1          3      7        2170            400      1951  47.7210 -122.319
# 2          3      6         770              0      1933  47.7379 -122.233
# 3          5      7        1050            910      1965  47.5208 -122.393
# 4          3      8        1680              0      1987  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %% [markdown]
# ## Data exploration <br>
# start with plotting the data of the houses according to longitude and latitude to see if there is any visual patterns

# %%
import matplotlib.pyplot as plt

houses.plot(kind='scatter', x = "long", y='lat', s=(houses['sqft_living'])/100, label='House price', c='price', cmap=plt.get_cmap("jet"))
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %% [markdown]
# # Correlation matrix
#
# now we try to find the correlations between deferent features

# %%
correlation_matrix = houses.corr()
correlation_matrix.style.background_gradient(cmap='jet')
# Out:
# <style type="text/css">
# #T_c4edd_row0_col0, #T_c4edd_row1_col1, #T_c4edd_row2_col2, #T_c4edd_row3_col3, #T_c4edd_row4_col4, #T_c4edd_row5_col5, #T_c4edd_row6_col6, #T_c4edd_row7_col7, #T_c4edd_row8_col8, #T_c4edd_row9_col9, #T_c4edd_row10_col10, #T_c4edd_row11_col11, #T_c4edd_row12_col12, #T_c4edd_row13_col13, #T_c4edd_row14_col14, #T_c4edd_row15_col15 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_c4edd_row0_col1, #T_c4edd_row13_col15 {
#   background-color: #00c0ff;
#   color: #000000;
# }
# #T_c4edd_row0_col2, #T_c4edd_row13_col11, #T_c4edd_row14_col2 {
#   background-color: #b1ff46;
#   color: #000000;
# }
# #T_c4edd_row0_col3 {
#   background-color: #ffb600;
#   color: #000000;
# }
# #T_c4edd_row0_col4, #T_c4edd_row5_col1, #T_c4edd_row11_col1 {
#   background-color: #0024ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row0_col5 {
#   background-color: #33ffc4;
#   color: #000000;
# }
# #T_c4edd_row0_col6, #T_c4edd_row1_col8 {
#   background-color: #49ffad;
#   color: #000000;
# }
# #T_c4edd_row0_col7, #T_c4edd_row12_col0, #T_c4edd_row13_col4 {
#   background-color: #00a8ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row0_col8 {
#   background-color: #ffbd00;
#   color: #000000;
# }
# #T_c4edd_row0_col9, #T_c4edd_row2_col8 {
#   background-color: #feed00;
#   color: #000000;
# }
# #T_c4edd_row0_col10 {
#   background-color: #53ffa4;
#   color: #000000;
# }
# #T_c4edd_row0_col11, #T_c4edd_row8_col6 {
#   background-color: #00b8ff;
#   color: #000000;
# }
# #T_c4edd_row0_col12, #T_c4edd_row14_col1 {
#   background-color: #26ffd1;
#   color: #000000;
# }
# #T_c4edd_row0_col13, #T_c4edd_row1_col6, #T_c4edd_row6_col4, #T_c4edd_row6_col15, #T_c4edd_row11_col15 {
#   background-color: #0014ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row0_col14 {
#   background-color: #deff19;
#   color: #000000;
# }
# #T_c4edd_row0_col15, #T_c4edd_row2_col15, #T_c4edd_row5_col12 {
#   background-color: #001cff;
#   color: #f1f1f1;
# }
# #T_c4edd_row1_col0, #T_c4edd_row4_col9 {
#   background-color: #00acff;
#   color: #f1f1f1;
# }
# #T_c4edd_row1_col2 {
#   background-color: #90ff66;
#   color: #000000;
# }
# #T_c4edd_row1_col3 {
#   background-color: #ceff29;
#   color: #000000;
# }
# #T_c4edd_row1_col4, #T_c4edd_row1_col15 {
#   background-color: #0000fa;
#   color: #f1f1f1;
# }
# #T_c4edd_row1_col5, #T_c4edd_row6_col8 {
#   background-color: #00e0fb;
#   color: #000000;
# }
# #T_c4edd_row1_col7 {
#   background-color: #00a4ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row1_col9 {
#   background-color: #a4ff53;
#   color: #000000;
# }
# #T_c4edd_row1_col10 {
#   background-color: #46ffb1;
#   color: #000000;
# }
# #T_c4edd_row1_col11 {
#   background-color: #16ffe1;
#   color: #000000;
# }
# #T_c4edd_row1_col12, #T_c4edd_row7_col6, #T_c4edd_row7_col12, #T_c4edd_row9_col12, #T_c4edd_row11_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row1_col13 {
#   background-color: #0074ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row1_col14 {
#   background-color: #4dffaa;
#   color: #000000;
# }
# #T_c4edd_row2_col0, #T_c4edd_row3_col11, #T_c4edd_row11_col2 {
#   background-color: #7aff7d;
#   color: #000000;
# }
# #T_c4edd_row2_col1 {
#   background-color: #63ff94;
#   color: #000000;
# }
# #T_c4edd_row2_col3 {
#   background-color: #ffb900;
#   color: #000000;
# }
# #T_c4edd_row2_col4, #T_c4edd_row2_col12, #T_c4edd_row8_col7, #T_c4edd_row12_col11 {
#   background-color: #0020ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row2_col5 {
#   background-color: #d1ff26;
#   color: #000000;
# }
# #T_c4edd_row2_col6, #T_c4edd_row3_col4 {
#   background-color: #0070ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row2_col7, #T_c4edd_row3_col12 {
#   background-color: #0030ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row2_col9, #T_c4edd_row5_col11 {
#   background-color: #ffd000;
#   color: #000000;
# }
# #T_c4edd_row2_col10, #T_c4edd_row10_col7, #T_c4edd_row13_col14 {
#   background-color: #23ffd4;
#   color: #000000;
# }
# #T_c4edd_row2_col11, #T_c4edd_row5_col9 {
#   background-color: #c1ff36;
#   color: #000000;
# }
# #T_c4edd_row2_col13, #T_c4edd_row6_col9, #T_c4edd_row13_col3 {
#   background-color: #00a0ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row2_col14 {
#   background-color: #a7ff50;
#   color: #000000;
# }
# #T_c4edd_row3_col0 {
#   background-color: #ffc800;
#   color: #000000;
# }
# #T_c4edd_row3_col1 {
#   background-color: #beff39;
#   color: #000000;
# }
# #T_c4edd_row3_col2 {
#   background-color: #ffa700;
#   color: #000000;
# }
# #T_c4edd_row3_col5, #T_c4edd_row11_col9 {
#   background-color: #7dff7a;
#   color: #000000;
# }
# #T_c4edd_row3_col6, #T_c4edd_row3_col13 {
#   background-color: #00d8ff;
#   color: #000000;
# }
# #T_c4edd_row3_col7, #T_c4edd_row4_col3, #T_c4edd_row4_col5, #T_c4edd_row5_col0 {
#   background-color: #0060ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row3_col8, #T_c4edd_row8_col9 {
#   background-color: #ff6f00;
#   color: #f1f1f1;
# }
# #T_c4edd_row3_col9 {
#   background-color: #fa0f00;
#   color: #f1f1f1;
# }
# #T_c4edd_row3_col10, #T_c4edd_row5_col2, #T_c4edd_row5_col8 {
#   background-color: #9dff5a;
#   color: #000000;
# }
# #T_c4edd_row3_col14, #T_c4edd_row8_col3 {
#   background-color: #ff7e00;
#   color: #f1f1f1;
# }
# #T_c4edd_row3_col15, #T_c4edd_row9_col4, #T_c4edd_row12_col5, #T_c4edd_row14_col15 {
#   background-color: #007cff;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col0, #T_c4edd_row5_col15 {
#   background-color: #0000cd;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col1 {
#   background-color: #0000ad;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col2, #T_c4edd_row8_col15 {
#   background-color: #0040ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col6 {
#   background-color: #0010ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col7, #T_c4edd_row9_col15 {
#   background-color: #0088ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col8, #T_c4edd_row6_col11, #T_c4edd_row10_col12, #T_c4edd_row12_col8 {
#   background-color: #0064ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col10, #T_c4edd_row15_col10 {
#   background-color: #0050ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col11, #T_c4edd_row15_col9 {
#   background-color: #00b4ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col12, #T_c4edd_row15_col12 {
#   background-color: #0000bb;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col13, #T_c4edd_row6_col3, #T_c4edd_row8_col10 {
#   background-color: #00ccff;
#   color: #000000;
# }
# #T_c4edd_row4_col14, #T_c4edd_row15_col5 {
#   background-color: #005cff;
#   color: #f1f1f1;
# }
# #T_c4edd_row4_col15, #T_c4edd_row15_col4 {
#   background-color: #ff9f00;
#   color: #000000;
# }
# #T_c4edd_row5_col3 {
#   background-color: #1fffd7;
#   color: #000000;
# }
# #T_c4edd_row5_col4, #T_c4edd_row7_col4, #T_c4edd_row13_col10 {
#   background-color: #0000d1;
#   color: #f1f1f1;
# }
# #T_c4edd_row5_col6, #T_c4edd_row10_col15 {
#   background-color: #0000ed;
#   color: #f1f1f1;
# }
# #T_c4edd_row5_col7 {
#   background-color: #0000b6;
#   color: #f1f1f1;
# }
# #T_c4edd_row5_col10, #T_c4edd_row7_col2, #T_c4edd_row7_col3, #T_c4edd_row7_col5, #T_c4edd_row7_col8, #T_c4edd_row7_col9, #T_c4edd_row7_col11, #T_c4edd_row7_col14, #T_c4edd_row10_col13, #T_c4edd_row11_col7, #T_c4edd_row11_col12, #T_c4edd_row12_col1, #T_c4edd_row12_col4, #T_c4edd_row12_col15, #T_c4edd_row13_col0, #T_c4edd_row13_col6 {
#   background-color: #000080;
#   color: #f1f1f1;
# }
# #T_c4edd_row5_col13, #T_c4edd_row15_col7 {
#   background-color: #008cff;
#   color: #f1f1f1;
# }
# #T_c4edd_row5_col14, #T_c4edd_row11_col3 {
#   background-color: #06ecf1;
#   color: #000000;
# }
# #T_c4edd_row6_col0, #T_c4edd_row11_col14 {
#   background-color: #1cffdb;
#   color: #000000;
# }
# #T_c4edd_row6_col1 {
#   background-color: #0000e3;
#   color: #f1f1f1;
# }
# #T_c4edd_row6_col2, #T_c4edd_row10_col14 {
#   background-color: #0090ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row6_col5 {
#   background-color: #0078ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row6_col7, #T_c4edd_row8_col13, #T_c4edd_row13_col8 {
#   background-color: #00b0ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row6_col10 {
#   background-color: #36ffc1;
#   color: #000000;
# }
# #T_c4edd_row6_col12, #T_c4edd_row12_col9 {
#   background-color: #0008ff;
#   color: #f1f1f1;
# }
# #T_c4edd_row6_col13 {
#   background-color: #0000bf;
#   color: #f1f1f1;
# }
# #T_c4edd_row6_col14 {
#   background-color: #00dcfe;
#   color: #000000;
# }
# #T_c4edd_row7_col0 {
#   background-color: #00008d;
#   color: #f1f1f1;
# }
# #T_c4edd_row7_col1, #T_c4edd_row15_col1 {
#   background-color: #0000a8;
#   color: #f1f1f1;
# }
# #T_c4edd_row7_col10, #T_c4edd_row10_col6 {
#   background-color: #00d0ff;
#   color: #000000;
# }
# #T_c4edd_row7_col13, #T_c4edd_row11

# %% [markdown]
# ## plot the strongly correlated data

# %%
plt.subplot(2,2,1)
plt.scatter(x=houses['price'], y=houses['sqft_living'])
plt.xlabel('price')
plt.ylabel('sqft_living')

plt.subplot(2,2,2)
plt.scatter(x=houses['sqft_living'], y=houses['sqft_living15'])
plt.xlabel('sqft_living')
plt.ylabel('sqft_living15')

plt.subplot(2,2,3)
plt.scatter(x=houses['sqft_living'], y=houses['sqft_above'])
plt.xlabel('sqft_living')
plt.ylabel('sqft_above')

plt.subplot(2,2,4)
plt.scatter(x=houses['sqft_lot'], y=houses['sqft_lot15'])
plt.xlabel('sqft_lot')
plt.ylabel('sqft_lot15')

plt.tight_layout()
